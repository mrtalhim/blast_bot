# %%
import pandas as pd

df = pd.read_csv('./list_ujian (3).csv', header=None)

# %%
df.sample(5)
# Out:
#          0                    1                        2      3             4  \
# 2268  2271  2023-05-28 07:55:04    Ilman Munadyan Salman  18704  8.572459e+10
# 2488  2491  2023-06-09 20:03:30      Rifki Mubarik Ahmad  20881  8.961789e+10
# 2863  2867  2023-07-21 18:59:20          Ervin Nurrohman  56387  8.138739e+10
# 599    602  2023-03-19 11:44:10  Mohammad Hakim Nuruddin  45327           NaN
# 2930  2934  2023-07-22 13:56:29             Haeru Bachri  41663  8.596028e+10
#
#           5    6        7      8
# 2268   42.0  CSA  2023-05   82.0
# 2488   93.0  NGR  2023-06  100.0
# 2863   77.0  JPA  2023-07  100.0
# 599   144.0  NaN  2023-03   46.0
# 2930  109.0  PTR  2023-07   64.0

# %%
df[3] = pd.to_datetime(df[1]).dt.date

# %%
df[(df[1] >= '2023-06-01')]
# Out:
#          0                    1                      2      3             4  \
# 2270  2273  2023-06-02 13:05:02          Ahmad Mubarik  33963  8.770870e+10
# 2271  2274  2023-06-04 21:33:59              Saripudin  12176  8.578284e+10
# 2272  2275  2023-06-04 22:39:58         Muhammad Talha  18261  8.532012e+10
# 2273  2276  2023-06-04 22:42:16          Nur Ariyansah  12177  8.581084e+10
# 2274  2277  2023-06-05 14:01:33     Danis Ahmad Fauzan  59894  8.577503e+10
# ...    ...                  ...                    ...    ...           ...
# 3127  3131  2023-07-26 18:11:36            Ade Suriadi  50476  8.529535e+10
# 3128  3132  2023-07-26 20:55:21     Abdul Aleem Naweed  41198  8.129655e+10
# 3129  3133  2023-07-26 21:11:39      Fadly Ahmad Ayyub  44886  8.581435e+10
# 3130  3134  2023-07-27 05:23:45      Fathan Abdussalam  13292  8.780904e+10
# 3131  3135  2023-07-27 05:51:01  Iyza Ur-Rahman Naweed  41199  8.953218e+11
#
#           5    6        7      8
# ...

# %%
df1 = df[(df[1] < '2023-06-01') & (df[1] >= '2023-05-01')]
df2 = df[df[1] >= '2023-07-01']

# %%
df1.sample(5)
# Out:
#          0                    1                          2      3  \
# 1418  1421  2023-05-07 10:43:20        Azhra Rey Syahputra  74776
# 2076  2079  2023-05-19 11:11:57                    Hamidin  28784
# 2099  2102  2023-05-20 18:49:28  Revaldi Maulana Nurhikmat  61612
# 1733  1736  2023-05-14 21:05:04              Nur Fatahudin  59814
# 1533  1536  2023-05-09 19:24:11    Muhammad Rizal Julianto  70997
#
#                  4      5    6        7     8
# 1418  8.221906e+10  133.0  SDG  2023-05   NaN
# 2076  8.129381e+10  175.0  MKW  2023-05  91.0
# 2099  8.384721e+10  110.0  PRN  2023-05  82.0
# 1733  8.121108e+08  106.0  PGN  2023-05  91.0
# 1533  8.125020e+10  149.0  THG  2023-05  46.0

# %%
df1[3].nunique()
# Out:
# 913

# %%
df1 = df1.assign(result = df1[3].isin(df2[3]))

# %%
df1 = df1[df1['result'] == False].drop_duplicates(3)

# %%
import re
from app import send

def new(x):
    name = x[2]
    number = int(x[4])
    number = str(number)
    number = re.sub('8', '628', number, 1)
    # print(number)
    return build_message(name, number)

def build_message(name, number):
    message = """UJIAN KHUDDAM

Assalamualaikum wr wb, 
Yth *%NAMA%*

Apakah tuan sudah mengerjakan Ujian Khuddam Bulan Juli 2023? Kerjain yuk 😊 Deadlinenya sampai tanggal 31 Juli 2023 pukul 23.59 ya📝

link ujiannya:
https://mkai.dcidn.com/ujian

Referensi buku yang digunakan pada ujian kali ini diambil dari:
1. Buku Buku Karakteristik Orang-Orang Shalih (Siratul Abdal) hal. 5-11 karya Hadhrat Mirza Ghulam Ahmad a.s.
Link buku: https://bit.ly/SiratulAbdal

Ayo isi ujian!
Selamat mengerjakan yaa!


Yang Lemah
_Muhtamim Ta‘lim_""".replace('%NAMA%', name)
    to_send = {
        'phone_number': number,
        'message': message
    }
    return send(to_send)

# %%
test = pd.concat([df[df[2] == 'Rashid Ahmad'].tail(1), df[df[2] == 'Saripudin'].tail(1)])

# %%
test.apply(new, axis=1)
# Out:
# sending...
# 200
# sending...
# 200
# 2785    None
# 2784    None
# dtype: object

# %%
df1[[2, 3, 4]].iloc[1:].apply(new, axis=1)
# Out:
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# sending...
# 200
# ...

# %%
df1[[2,3,4]].nunique()
# Out:
# 2    651
# 3    666
# 4    662
# dtype: int64
